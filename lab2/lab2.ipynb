# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math as mth
import matplotlib.patches as patches
from scipy import stats as st
plt.rcParams.update({'figure.max_open_warning': 0})
from plotly.offline import init_notebook_mode, iplot
import plotly
import plotly.graph_objs as go

# %%
df = pd.read_csv('nhldraft.csv')

# %%
df.head()
# Out:
#    id  year  overall_pick                 team            player nationality  \
# 0   1  2022             1   Montreal Canadiens  Juraj Slafkovsky          SK
# 1   2  2022             2    New Jersey Devils       Simon Nemec          SK
# 2   3  2022             3      Arizona Coyotes      Logan Cooley          US
# 3   4  2022             4       Seattle Kraken      Shane Wright          CA
# 4   5  2022             5  Philadelphia Flyers   Cutter Gauthier          SE
#
#   position   age  to_year                           amateur_team  ...  points  \
# 0       LW  18.0      NaN                          TPS (Finland)  ...     NaN
# 1        D  18.0      NaN                    HK Nitra (Slovakia)  ...     NaN
# 2        C  18.0      NaN  USA U-18 Development Team (USDP/USHL)  ...     NaN
# 3        C  18.0      NaN              Kingston Frontenacs (OHL)  ...     NaN
# 4       LW  18.0      NaN  USA U-18 Development Team (USDP/USHL)  ...     NaN
#
#    plus_minus  penalties_minutes  goalie_games_played  goalie_wins  \
# 0         NaN                NaN                  NaN          NaN
# 1         NaN                NaN                  NaN          NaN
# 2         NaN                NaN                  NaN          NaN
# 3         NaN                NaN                  NaN          NaN
# 4         NaN                NaN                  NaN          NaN
#
#    goalie_losses  goalie_ties_overtime  save_percentage  \
# 0            NaN                   NaN              NaN
# 1            NaN                   NaN              NaN
# 2            NaN                   NaN              NaN
# 3            NaN                   NaN              NaN
# 4            NaN                   NaN              NaN
#
#    goals_against_average  point_shares
# 0                    NaN           NaN
# 1                    NaN           NaN
# 2                    NaN           NaN
# 3                    NaN           NaN
# 4                    NaN           NaN
#
# [5 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12250 entries, 0 to 12249
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     12250 non-null  int64
#  1   year                   12250 non-null  int64
#  2   overall_pick           12250 non-null  int64
#  3   team                   12249 non-null  object
#  4   player                 12250 non-null  object
#  5   nationality            12246 non-null  object
#  6   position               12223 non-null  object
#  7   age                    8291 non-null   float64
#  8   to_year                5246 non-null   float64
#  9   amateur_team           12250 non-null  object
#  10  games_played           5246 non-null   float64
#  11  goals                  5246 non-null   float64
#  12  assists                5246 non-null   float64
#  13  points                 5246 non-null   float64
#  14  plus_minus             5234 non-null   float64
#  15  penalties_minutes      5246 non-null   float64
#  16  goalie_games_played    490 non-null    float64
#  17  goalie_wins            488 non-null    float64
#  18  goalie_losses          488 non-null    float64
#  19  goalie_ties_overtime   488 non-null    float64
#  20  save_percentage        488 non-null    float64
#  21  goals_against_average  490 non-null    float64
#  22  point_shares           5246 non-null   float64
# dtypes: float64(15), int64(3), object(5)
# memory usage: 2.1+ MB

# %%
df.drop(df.columns[[0]],axis = 1, inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12250 entries, 0 to 12249
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   12250 non-null  int64
#  1   overall_pick           12250 non-null  int64
#  2   team                   12249 non-null  object
#  3   player                 12250 non-null  object
#  4   nationality            12246 non-null  object
#  5   position               12223 non-null  object
#  6   age                    8291 non-null   float64
#  7   to_year                5246 non-null   float64
#  8   amateur_team           12250 non-null  object
#  9   games_played           5246 non-null   float64
#  10  goals                  5246 non-null   float64
#  11  assists                5246 non-null   float64
#  12  points                 5246 non-null   float64
#  13  plus_minus             5234 non-null   float64
#  14  penalties_minutes      5246 non-null   float64
#  15  goalie_games_played    490 non-null    float64
#  16  goalie_wins            488 non-null    float64
#  17  goalie_losses          488 non-null    float64
#  18  goalie_ties_overtime   488 non-null    float64
#  19  save_percentage        488 non-null    float64
#  20  goals_against_average  490 non-null    float64
#  21  point_shares           5246 non-null   float64
# dtypes: float64(15), int64(2), object(5)
# memory usage: 2.1+ MB

# %%
df.drop(df.columns[[13]],axis = 1, inplace = True)
df.drop(df.columns[[13]],axis = 1, inplace = True)
df.drop(df.columns[[13]],axis = 1, inplace = True)
df.drop(df.columns[[13]],axis = 1, inplace = True)
df.drop(df.columns[[13]],axis = 1, inplace = True)
df.drop(df.columns[[13]],axis = 1, inplace = True)
df.drop(df.columns[[13]],axis = 1, inplace = True)
df.drop(df.columns[[13]],axis = 1, inplace = True)
df.drop(df.columns[[13]],axis = 1, inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12250 entries, 0 to 12249
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          12250 non-null  int64
#  1   overall_pick  12250 non-null  int64
#  2   team          12249 non-null  object
#  3   player        12250 non-null  object
#  4   nationality   12246 non-null  object
#  5   position      12223 non-null  object
#  6   age           8291 non-null   float64
#  7   to_year       5246 non-null   float64
#  8   amateur_team  12250 non-null  object
#  9   games_played  5246 non-null   float64
#  10  goals         5246 non-null   float64
#  11  assists       5246 non-null   float64
#  12  points        5246 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 1.2+ MB

# %%
df.dropna(subset=['to_year'],inplace = True, axis = 0)
df.isna().sum()
# Out:
# year            0
# overall_pick    0
# team            0
# player          0
# nationality     0
# position        0
# age             0
# to_year         0
# amateur_team    0
# games_played    0
# goals           0
# assists         0
# points          0
# dtype: int64

# %%
df.head()
# Out:
#      year  overall_pick                   team           player nationality  \
# 225  2021             1         Buffalo Sabres       Owen Power          CA
# 226  2021             2         Seattle Kraken  Matthew Beniers          US
# 227  2021             3          Anaheim Ducks   Mason Mctavish          CH
# 229  2021             5  Columbus Blue Jackets     Kent Johnson          CA
# 231  2021             7        San Jose Sharks   William Eklund          SE
#
#     position   age  to_year              amateur_team  games_played  goals  \
# 225        D  18.0   2022.0        Michigan (Big Ten)           8.0    2.0
# 226        C  18.0   2022.0        Michigan (Big Ten)          10.0    3.0
# 227        C  18.0   2022.0  Peterborough Petes (OHL)           9.0    2.0
# 229        C  18.0   2022.0        Michigan (Big Ten)           9.0    0.0
# 231       LW  18.0   2022.0   Djurgardens IF (Sweden)           9.0    0.0
#
#      assists  points
# 225      1.0     3.0
# 226      6.0     9.0
# 227      1.0     3.0
# 229      3.0     3.0
# 231      4.0     4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5246 entries, 225 to 12249
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          5246 non-null   int64
#  1   overall_pick  5246 non-null   int64
#  2   team          5246 non-null   object
#  3   player        5246 non-null   object
#  4   nationality   5246 non-null   object
#  5   position      5246 non-null   object
#  6   age           5246 non-null   float64
#  7   to_year       5246 non-null   float64
#  8   amateur_team  5246 non-null   object
#  9   games_played  5246 non-null   float64
#  10  goals         5246 non-null   float64
#  11  assists       5246 non-null   float64
#  12  points        5246 non-null   float64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 573.8+ KB

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
# %matplotlib inline

# %%
new_dummies = pd.get_dummies(df['position'], prefix='position')
new_data = pd.concat([df, new_dummies], axis=1)
new_data.drop('position', axis=1, inplace=True)
new_data
# Out:
#        year  overall_pick                   team           player nationality  \
# 225    2021             1         Buffalo Sabres       Owen Power          CA
# 226    2021             2         Seattle Kraken  Matthew Beniers          US
# 227    2021             3          Anaheim Ducks   Mason Mctavish          CH
# 229    2021             5  Columbus Blue Jackets     Kent Johnson          CA
# 231    2021             7        San Jose Sharks   William Eklund          SE
# ...     ...           ...                    ...              ...         ...
# 12229  1963             1     Montreal Canadiens    Garry Monahan          CA
# 12230  1963             2      Detroit Red Wings   Pete Mahovlich          CA
# 12234  1963             6    Toronto Maple Leafs   Walt McKechnie          CA
# 12245  1963            17    Toronto Maple Leafs      Jim McKenny          CA
# 12249  1963            21    Toronto Maple Leafs     Gerry Meehan          CA
#
#         age  to_year                           amateur_team  games_played  \
# 225    18.0   2022.0                     Michigan (Big Ten)           8.0
# 226    18.0   2022.0                     Michigan (Big Ten)          10.0
# 227    18.0   2022.0               Peterborough Petes (OHL)           9.0
# 229    18.0   2022.0                     Michigan (Big Ten)           9.0
# 231    18.0   2022.0                Djurgardens IF (Sweden)           9.0
# ...     ...      ...                                    ...           ...
# 12229  16.0   1979.0                St. Michael's Majors ()         748.0
# 12230  16.0   1981.0                St. Michael's Majors ()         883.0
# 12234  16.0   1983.0                        London (WOJBHL)         955.0
# 12245  16.0   1979.0  Toronto Neil McNeil Maroons (MetJAHL)         604.0
# 12249  17.0   1979.0  Toronto Neil McNeil Maroons (MetJAHL)         670.0
#
#        goals  ...  position_F  position_G  position_L/RW  position_LW  \
# 225      2.0  ...           0           0              0            0
# 226      3.0  ...           0           0              0            0
# 227      2.0  ...           0           0              0            0
# 229      0.0  ...           0           0              0            0
# 231      0.0  ...           0           0              0            1
# ...      ...  ...         ...         ...            ...          ...
# 12229  116.0  ...           0           0              0            1
# 12230  288.0  ...           0           0              0            0
# 12234  214.0  ...           0           0              0            0
# 12245   82.0  ...           0           0              0            0
# 12249  180.0  ...           0           0              0            0
#
#        position_LW/C  position_LW/D  position_RW  position_RW/C  \
# 225                0              0            0              0
# 226                0              0            0              0
# 227                0              0            0              0
# 229                0              0            0              0
# 231                0              0            0              0
# ...              ...            ...          ...            ...
# 12229              0              0            0              0
# 12230              0              0            0              0
# 12234              0              0            0              0
# 12245              0              0            0              0
# 12249              0              0            0              0
#
#        position_RW/D  position_W
# 225                0           0
# 226                0           0
# 227                0           0
# 229                0           0
# 231                0           0
# ...              ...         ...
# 12229              0           0
# 12230              0           0
# 12234              0           0
# 12245              0           0
# 12249              0           0
#
# [5246 rows x 33 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
new_data['age_scaled'] = scaler.fit_transform(new_data[['age']])

# %%
new_data
# Out:
#        year  overall_pick                   team           player nationality  \
# 225    2021             1         Buffalo Sabres       Owen Power          CA
# 226    2021             2         Seattle Kraken  Matthew Beniers          US
# 227    2021             3          Anaheim Ducks   Mason Mctavish          CH
# 229    2021             5  Columbus Blue Jackets     Kent Johnson          CA
# 231    2021             7        San Jose Sharks   William Eklund          SE
# ...     ...           ...                    ...              ...         ...
# 12229  1963             1     Montreal Canadiens    Garry Monahan          CA
# 12230  1963             2      Detroit Red Wings   Pete Mahovlich          CA
# 12234  1963             6    Toronto Maple Leafs   Walt McKechnie          CA
# 12245  1963            17    Toronto Maple Leafs      Jim McKenny          CA
# 12249  1963            21    Toronto Maple Leafs     Gerry Meehan          CA
#
#         age  to_year                           amateur_team  games_played  \
# 225    18.0   2022.0                     Michigan (Big Ten)           8.0
# 226    18.0   2022.0                     Michigan (Big Ten)          10.0
# 227    18.0   2022.0               Peterborough Petes (OHL)           9.0
# 229    18.0   2022.0                     Michigan (Big Ten)           9.0
# 231    18.0   2022.0                Djurgardens IF (Sweden)           9.0
# ...     ...      ...                                    ...           ...
# 12229  16.0   1979.0                St. Michael's Majors ()         748.0
# 12230  16.0   1981.0                St. Michael's Majors ()         883.0
# 12234  16.0   1983.0                        London (WOJBHL)         955.0
# 12245  16.0   1979.0  Toronto Neil McNeil Maroons (MetJAHL)         604.0
# 12249  17.0   1979.0  Toronto Neil McNeil Maroons (MetJAHL)         670.0
#
#        goals  ...  position_G  position_L/RW  position_LW  position_LW/C  \
# 225      2.0  ...           0              0            0              0
# 226      3.0  ...           0              0            0              0
# 227      2.0  ...           0              0            0              0
# 229      0.0  ...           0              0            0              0
# 231      0.0  ...           0              0            1              0
# ...      ...  ...         ...            ...          ...            ...
# 12229  116.0  ...           0              0            1              0
# 12230  288.0  ...           0              0            0              0
# 12234  214.0  ...           0              0            0              0
# 12245   82.0  ...           0              0            0              0
# 12249  180.0  ...           0              0            0              0
#
#        position_LW/D  position_RW  position_RW/C  position_RW/D  position_W  \
# 225                0            0              0              0           0
# 226                0            0              0              0           0
# 227                0            0              0              0           0
# 229                0            0              0              0           0
# 231                0            0              0              0           0
# ...              ...          ...            ...            ...         ...
# 12229              0            0              0              0           0
# 12230              0            0              0              0           0
# 12234              0            0              0              0           0
# 12245              0            0              0              0           0
# 12249              0            0              0              0           0
#
#        age_scaled
# 225      0.095238
# 226      0.095238
# 227      0.095238
# 229      0.095238
# 231      0.095238
# ...           ...
# 12229    0.000000
# 12230    0.000000
# 12234    0.000000
# 12245    0.000000
# 12249    0.047619
#
# [5246 rows x 34 columns]
